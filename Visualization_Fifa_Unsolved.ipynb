# %% [markdown]
# # Fifa19 Exercise - Solutions
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [Fifa19 Dataset](https://www.kaggle.com/winterbreeze/fifa19eda) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# #### Read fifa_eda.csv

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize': [15, 10]}, font_scale=1.2)
sns.set_palette('rocket')

# %%
df = pd.read_csv('fifa_eda.csv')

# %%
df.head(3)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0

# %% [markdown]
# ### New Part Visualiztion Questions

# %% [markdown]
# #### Draw the outliers of players value

# %%
sns.boxplot(data = df , x = 'Value' , palette = 'hls')
# Out:
# <AxesSubplot:xlabel='Value'>

# %% [markdown]
# #### find the average wage for each Nationality and draw the outliers in value for the top 5 nationality

# %% [markdown]
# * find the average wage for each Nationality

# %%
print(df.columns)
df.groupby('Nationality')['Wage'].mean().sort_values(ascending = False)
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')
# Nationality
# Dominican Republic      71.000000
# United Arab Emirates    39.000000
# Gabon                   26.933333
# Armenia                 22.000000
# Croatia                 21.682540
#                           ...
# Belize                   1.000000
# Andorra                  1.000000
# Jordan                   1.000000
# Bolivia                  0.833333
# India                    0.000000
# Name: Wage, Length: 164, dtype: float64

# %%
df.groupby('Nationality')['Value'].mean().sort_values(ascending = False)
# Out:
# Nationality
# United Arab Emirates    10500.000000
# Dominican Republic      10400.000000
# Central African Rep.    10050.000000
# Egypt                    6658.750000
# Gabon                    6628.333333
#                             ...
# Indonesia                 180.000000
# Botswana                  160.000000
# Hong Kong                 145.000000
# Puerto Rico               110.000000
# India                            NaN
# Name: Value, Length: 164, dtype: float64

# %% [markdown]
# * draw the outliers in value for the top 5 nationality

# %%
top5 = df.groupby('Nationality')['Value'].mean().sort_values(ascending = False).head()
top5
# Out:
# Nationality
# United Arab Emirates    10500.000000
# Dominican Republic      10400.000000
# Central African Rep.    10050.000000
# Egypt                    6658.750000
# Gabon                    6628.333333
# Name: Value, dtype: float64

# %%
top_5 = df [ df['Nationality'].isin(top5.index) ]
top_5
# Out:
#            ID                   Name  Age           Nationality  Overall  \
# 26     209331               M. Salah   26                 Egypt       88
# 33     188567          P. Aubameyang   29                 Gabon       88
# 262    201455           G. Kondogbia   25  Central African Rep.       82
# 430    221639                Mariano   24    Dominican Republic       80
# 752    226078              Trezeguet   23                 Egypt       78
# 793    212811              M. Lemina   24                 Gabon       78
# 959    213051              M. Elneny   25                 Egypt       77
# 1170   245221         O. Abdulrahman   26  United Arab Emirates       77
# 1517   210648              A. Hegazi   27                 Egypt       76
# 1795   213353               K. Kanga   27                 Gabon       75
# 2241   210259              A. Hassan   25                 Egypt       74
# 2259   219740                Kahraba   24                 Egypt       74
# 2293   188270        B. Ecuélé Manga   29                 Gabon       74
# 2334   233601               R. Sobhi   21                 Egypt       74
# 3310   191005          A. Elmohamady   30                 Egypt       72
# 3616   233600               A. Warda   24                 Egypt       72
# 3703   225951             D. Bouanga   23                 Gabon       72
# 3743   205998         A. Biyogo Poko   25                 Gabon       72
# 3929   212469              A. Ghazal   26                 Egypt       72
# 3942   213498  S. Martinsson Ngouali   26                 Gabon       72
# 4044   229404               A. Tarek   26                 Egypt       71
# 4217   170828              Shikabala   32                 Egypt       71
# 4504   197300             A. El Said   32                 Egypt       71
# 5256   225934             C. Yambéré   27  Central African Rep.       70
# 5614   175608               A. Fathi   33                 Egypt       70
# 5913   243533               M. Hamdy   23                 Egypt       69
# 5944   197975               S. Morsy   26                 Egypt       69
# 6021   228203              A. Ashraf   27                 Egypt       69
# 6407   169423              S. Ekramy   34                 Egypt       69
# 6620   212483              J. Obiang   24                 Gabon       68
# 6717   226077                A. Gabr   29                 Egypt       68
# 6804   212783               O. Gaber   26                 Egypt       68
# 7102   212088         M. Abdul Shafy   33                 Egypt       68
# 7132   207744               A. Youga   25  Central African Rep.       68
# 7455   202708               L. Palun   29                 Gabon       68
# 7765   199963          M. Tandjigora   28                 Gabon       67
# 8325   156313              A. El-Abd   33                 Egypt       67
# 8441   222134               T. Hamed   29                 Egypt       67
# 9165   228182          M. El-Shenawy   29                 Egypt       66
# 9228   228197            H. El Sayed   26                 Egypt       66
# 9297   241781                M. Awad   25                 Egypt       66
# 9514   227746            A. Jakobsen   24                 Egypt       66
# 9665   224198               K. Hafez   22                 Egypt       66
# 9911   211453              M. Mohsen   29                 Egypt       66
# 10082  175141               D. Ovono   35                 Gabon       65
# 10672  242361                M. Atwa   27                 Egypt       65
# 11458  243314             L. Quezada   22    Dominican Republic       64
# 13187  239910           A. Boupendza   21                 Gabon       62
# 13700  244923      J. Branger-Engone   24                 Gabon       62
# 13891  243954             A. Mostafa   20                 Egypt       62
# 14309  244099     L. Ameka Autchanga   21                 Gabon       61
# 16187  245454               W. Ebane   26                 Gabon       58
#
#        Potential                            Club    Value   Wage  \
# 26            89                       Liverpool  69500.0  255.0
# 33            88                         Arsenal  59000.0  265.0
# 262           85                     Valencia CF  27500.0   46.0
# 430           85                     Real Madrid  20000.0  140.0
# 752           80                    Kasimpaşa SK  13000.0   15.0
# 793           83                     Southampton  13500.0   44.0
# 959           79                         Arsenal   9000.0   76.0
# 1170          78                        Al Hilal  10500.0   39.0
# 1517          78            West Bromwich Albion   7500.0   31.0
# 1795          75                    Sparta Praha   7000.0    1.0
# 2241          78                  Olympiacos CFP   7500.0    1.0
# 2259          79                             NaN      NaN    0.0
# 2293          74                    Cardiff City   4400.0   37.0
# 2334          79               Huddersfield Town   7500.0   29.0
# 3310          72                     Aston Villa   2200.0   14.0
# 3616          75                            PAOK   3900.0    1.0
# 3703          77                 Nîmes Olympique   4200.0   12.0
# 3743          76                      Göztepe SK   3900.0   17.0
# 3929          75          Vancouver Whitecaps FC   3200.0    6.0
# 3942          74                     Hammarby IF   3700.0    5.0
# 4044          74                 Orlando City SC   2500.0    5.0
# 4217          71                             NaN      NaN    0.0
# 4504          71                         Al Ahli   1800.0   23.0
# 5256          72                       Dijon FCO   1700.0    8.0
# 5614          70                             NaN      NaN    0.0
# 5913          79                             NaN      NaN    0.0
# 5944          71                  Wigan Athletic   1100.0   22.0
# 6021          69                             NaN      NaN    0.0
# 6407          69                             NaN      NaN    0.0
# 6620          70                    ESTAC Troyes    900.0    3.0
# 6717          68                             NaN      NaN    0.0
# 6804          71                             NaN      NaN    0.0
# 7102          68                         Al Ahli    350.0   13.0
# 7132          71                     Le Havre AC    950.0    3.0
# 7455          68               KSV Cercle Brugge    675.0    6.0
# 7765          67                   Os Belenenses    625.0    3.0
# 8325          67               Wycombe Wanderers    300.0    3.0
# 8441          67                             NaN      NaN    0.0
# 9165          68                             NaN      NaN    0.0
# 9228          67                      Ettifaq FC    625.0    8.0
# 9297          69                        Al Wehda    575.0    5.0
# 9514          73                  IFK Norrköping    900.0    2.0
# 9665          73           Medipol Başakşehir FK    750.0    6.0
# 9911          66                             NaN      NaN    0.0
# 10082         65                        Paris FC    130.0    1.0
# 10672         66                         Al Raed    500.0    5.0
# 11458         76                      Córdoba CF    800.0    2.0
# 13187         72                     GFC Ajaccio    500.0    5.0
# 13700         65                 Oldham Athletic    375.0    3.0
# 13891         71                        KAA Gent    475.0    3.0
# 14309         71  Chamois Niortais Football Club    400.0    1.0
# 16187         59                      FC Lorient    120.0    1.0
#
#       Preferred Foot  International Reputation  Skill Moves Position  Joined  \
# 26              Left                       3.0          4.0       RM    2017
# 33             Right                       3.0          4.0       LM    2018
# 262             Left                       2.0          4.0       CM    2018
# 430            Right                       1.0          3.0       ST    2018
# 752            Right                       3.0          4.0       LM    2018
# 793            Right                       2.0          3.0      LCM    2017
# 959            Right                       1.0          3.0      RDM    2016
# 1170            Left                       2.0          5.0      CAM    2018
# 1517           Right                       1.0          2.0      LCB    2017
# 1795           Right                       1.0          4.0      RCM    2018
# 2241           Right                       1.0          3.0       ST    2015
# 2259           Right                       1.0          3.0       LM    2016
# 2293           Right                       1.0          2.0       RB    2014
# 2334           Right                       1.0          4.0       LM    2018
# 3310           Right                       2.0          3.0       RB    2017
# 3616           Right                       1.0          3.0       RM    2017
# 3703           Right                       1.0          3.0       LM    2018
# 3743           Right                       1.0          3.0      RDM    2018
# 3929           Right                       1.0          3.0      CDM    2017
# 3942           Right                       1.0          3.0      LCM    2017
# 4044            Left                       1.0          2.0       CB    2018
# 4217            Left                       1.0          5.0       LW    2016
# 4504           Right                       1.0          3.0      RCM    2018
# 5256           Right                       1.0          2.0       CB    2017
# 5614           Right                       2.0          3.0       RB    2016
# 5913           Right                       1.0          2.0       CB    2016
# 5944           Right                       1.0          3.0      CDM    2016
# 6021            Left                       1.0          3.0       LM    2016
# 6407           Right                       1.0          1.0       GK    2016
# 6620            Left                       1.0          3.0       LB    2016
# 6717           Right                       1.0          2.0      RCB    2016
# 6804           Right                       1.0          2.0       RB    2016
# 7102            Left                       1.0          3.0       LB    2015
# 7132           Right                       1.0          2.0      LDM    2017
# 7455           Right                       1.0          2.0       RB    2017
# 7765           Right                       1.0          2.0      CDM    2017
# 8325           Right                       1.0          2.0      LCB    2017
# 8441           Right                       1.0          2.0      LDM    2016
# 9165           Right                       1.0          1.0       GK    2016
# 9228            Left                       1.0          2.0       LB    2018
# 9297           Right                       1.0          1.0       GK    2018
# 9514           Right                       1.0          4.0       CM    2017
# 9665            Left                       1.0          3.0       LB    2018
# 9911           Right                       1.0          3.0       ST    2016
# 10082          Right                       1.0          1.0       GK    2017
# 10672          Right                       1.0          2.0      RCB    2018
# 11458           Left                       1.0          2.0       LM    2015
# 13187          Right                       1.0          2.0       ST    2016
# 13700           Left                       1.0          4.0       RM    2018
# 13891          Right                       1.0          2.0       LM    2018
# 14309          Right                       1.0          3.0       RM    2018
# 16187           Left                       1.0          2.0       LB    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 26              2023-01-01  5.750000   157.0   137300.000000
# 33              2021-01-01  6.166667   176.0   112100.000000
# 262             2022-01-01  6.166667   176.0    59800.000000
# 430             2023-01-01  5.916667   168.0    42500.000000
# 752             2021-01-01  5.833333   172.0    27000.000000
# 793             2022-01-01  6.000000   187.0    26700.000000
# 959             2022-01-01  5.916667   163.0    17800.000000
# 1170            2019-01-01  5.666667   132.0    18600.000000
# 1517            2022-01-01  6.333333   209.0    14800.000000
# 1795            2020-01-01  5.500000   148.0    15400.000000
# 2241            2021-01-01  6.250000   190.0    17100.000000
# 2259                   NaN  6.000000   168.0     4585.060806
# 2293            2019-01-01  6.083333   168.0     8700.000000
# 2334            2021-01-01  6.000000   170.0    14800.000000
# 3310            2020-01-01  6.000000   172.0     4300.000000
# 3616            2020-01-01  5.833333   170.0     8600.000000
# 3703            2021-01-01  5.916667   157.0     8600.000000
# 3743            2021-01-01  5.666667   159.0     8200.000000
# 3929            2019-01-01  6.166667   185.0     5100.000000
# 3942            2019-01-01  5.750000   165.0     4900.000000
# 4044            2023-01-01  6.250000   194.0     3900.000000
# 4217                   NaN  6.000000   163.0     4585.060806
# 4504            2020-01-01  5.750000   165.0     3100.000000
# 5256            2019-01-01  6.250000   185.0     3600.000000
# 5614                   NaN  5.750000   168.0     4585.060806
# 5913                   NaN  5.666667   159.0     4585.060806
# 5944            2019-01-01  5.666667   165.0     2100.000000
# 6021                   NaN  5.750000   161.0     4585.060806
# 6407                   NaN  6.333333   205.0     4585.060806
# 6620            2019-01-01  5.583333   141.0     1700.000000
# 6717                   NaN  6.250000   194.0     4585.060806
# 6804                   NaN  5.750000   157.0     4585.060806
# 7102            2019-01-01  5.583333   157.0      595.000000
# 7132            2020-01-01  6.083333   183.0     1700.000000
# 7455            2019-01-01  5.833333   170.0      979.000000
# 7765            2021-01-01  5.666667   150.0     1300.000000
# 8325            2020-01-01  5.916667   194.0      525.000000
# 8441                   NaN  5.583333   148.0     4585.060806
# 9165                   NaN  6.250000   190.0     4585.060806
# 9228            2020-01-01  5.583333   150.0     1100.000000
# 9297            2021-01-01  6.000000   139.0     1000.000000
# 9514            2020-01-01  5.916667   161.0     1300.000000
# 9665            2023-01-01  5.750000   161.0     1600.000000
# 9911                   NaN  6.083333   179.0     4585.060806
# 10082           2023-01-01  6.083333   190.0      228.000000
# 10672           2020-01-01  6.000000   172.0      863.000000
# 11458           2019-01-01  5.583333   146.0     1400.000000
# 13187           2019-06-30  5.916667   174.0     4585.060806
# 13700           2019-01-01  6.000000   163.0      684.000000
# 13891           2021-01-01  5.583333   139.0      808.000000
# 14309           2021-01-01  5.750000   150.0      780.000000
# 16187           2019-01-01  5.916667   176.0      219.000000

# %%
sns.boxplot(data = top_5 , x = 'Nationality' , y = 'Value' ,palette = 'Set3')
# Out:
# <AxesSubplot:xlabel='Nationality', ylabel='Value'>

# %%
sns.violinplot(data = top_5 , x = 'Nationality' , y = 'Value')
# Out:
# <AxesSubplot:xlabel='Nationality', ylabel='Value'>

# %%
df.groupby('Nationality')['Age'].agg(['max' , 'min' , 'mean' , 'median' , 'sum']).sort_values(by = 'mean' , ascending = False)
# Out:
#                    max  min       mean  median  sum
# Nationality
# Oman                36   36  36.000000    36.0   36
# Puerto Rico         34   34  34.000000    34.0   34
# Ethiopia            32   32  32.000000    32.0   32
# Trinidad & Tobago   44   26  31.750000    28.5  127
# Kuwait              31   31  31.000000    31.0   31
# ...                ...  ...        ...     ...  ...
# Zambia              29   18  22.222222    21.0  200
# Tanzania            25   19  22.000000    22.0   66
# Rwanda              21   21  21.000000    21.0   21
# Botswana            20   20  20.000000    20.0   20
# Indonesia           17   17  17.000000    17.0   17
#
# [164 rows x 5 columns]

# %% [markdown]
# #### Draw the distripution of players Height

# %%
sns.displot(data = df , x = 'Height')

# %%
sns.kdeplot(data = df , x = 'Height' , shade = True)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %% [markdown]
# #### What are the top 10 clubs in the wage and visualize the results ?

# %%
top10 = df.groupby('Club')['Wage'].sum().sort_values(ascending = False).head(10)
top10
# Out:
# Club
# Real Madrid          5017.0
# FC Barcelona         4837.0
# Manchester City      3741.0
# Manchester United    3391.0
# Juventus             3292.0
# Chelsea              3249.0
# Liverpool            2902.0
# Tottenham Hotspur    2623.0
# Arsenal              2588.0
# FC Bayern München    2286.0
# Name: Wage, dtype: float64

# %%
top_10 = df[df['Club'].isin(top10.index)]
top_10
# Out:
#            ID               Name  Age Nationality  Overall  Potential  \
# 0      158023           L. Messi   31   Argentina       94         94
# 1       20801  Cristiano Ronaldo   33    Portugal       94         94
# 3      193080             De Gea   27       Spain       91         93
# 4      192985       K. De Bruyne   27     Belgium       91         92
# 5      183277          E. Hazard   27     Belgium       91         91
# ...       ...                ...  ...         ...      ...        ...
# 16216  233442       J. Osei-Tutu   19     England       58         74
# 16403  233048    T. Dele-Bashiru   18     England       57         76
# 16806  238186           M. Bulka   18      Poland       56         74
# 16932  241859        R. Hoffmann   19     Germany       56         74
# 17451  224947        D. Grimshaw   20     England       54         68
#
#                     Club     Value   Wage Preferred Foot  \
# 0           FC Barcelona  110500.0  565.0           Left
# 1               Juventus   77000.0  405.0          Right
# 3      Manchester United   72000.0  260.0          Right
# 4        Manchester City  102000.0  355.0          Right
# 5                Chelsea   93000.0  340.0          Right
# ...                  ...       ...    ...            ...
# 16216            Arsenal     240.0    4.0          Right
# 16403    Manchester City     210.0    6.0          Right
# 16806            Chelsea     150.0    2.0          Right
# 16932  FC Bayern München     160.0    2.0          Right
# 17451    Manchester City     120.0    6.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# 5                           4.0          4.0       LF    2012
# ...                         ...          ...      ...     ...
# 16216                       1.0          2.0       RB    2015
# 16403                       1.0          2.0       CM    2017
# 16806                       1.0          1.0       GK    2016
# 16932                       1.0          1.0       GK    2017
# 17451                       1.0          1.0       GK    2016
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0        226500.0
# 1               2022-01-01  6.166667   183.0        127100.0
# 3               2020-01-01  6.333333   168.0        138600.0
# 4               2023-01-01  5.916667   154.0        196400.0
# 5               2020-01-01  5.666667   163.0        172100.0
# ...                    ...       ...     ...             ...
# 16216           2021-01-01  5.833333   159.0           606.0
# 16403           2019-01-01  5.833333   150.0           520.0
# 16806           2019-01-01  6.500000   198.0           371.0
# 16932           2021-01-01  6.333333   185.0           364.0
# 17451           2021-01-01  6.083333   170.0           297.0
#
# [318 rows x 18 columns]

# %%
sns.barplot(data = top_10 , y = 'Club' , x = 'Wage' ,
            estimator = np.sum , order = top10.index )
# Out:
# <AxesSubplot:xlabel='Wage', ylabel='Club'>

# %% [markdown]
# #### is there any outlier in the Age find it with 1- visualization 2-  with pandas ?

# %%
sns.boxplot(data = df , x = 'Age', color = 'y' )
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
ag_sts = df['Age'].describe()
ag_sts
# Out:
# count    18207.000000
# mean        25.122206
# std          4.669943
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         28.000000
# max         45.000000
# Name: Age, dtype: float64

# %%
IQR = ag_sts['75%'] - ag_sts['25%']
max_wisker = ag_sts['75%'] + (1.5 * IQR)
min_wisker = ag_sts['25%'] - (1.5 * IQR)

# %%
outlier = df[ (df['Age'] > max_wisker) | (df['Age'] < min_wisker)]

# %%
outlier
# Out:
#            ID                Name  Age        Nationality  Overall  Potential  \
# 41       1179           G. Buffon   40              Italy       88         88
# 554     49031       S. Sorrentino   39              Italy       80         80
# 864    153260              Hilton   40             Brazil       78         78
# 1120   156092           J. Villar   41           Paraguay       77         77
# 1294    14907         A. Bizzarri   40          Argentina       76         76
# 1952   161468          P. Guiñazú   39          Argentina       75         75
# 2225    25420          C. Pizarro   39               Peru       74         74
# 2706   110638           Cifuentes   39              Spain       73         73
# 2821   232543          S. Bertoli   40          Argentina       73         73
# 3128     7647         D. Dainelli   39              Italy       73         73
# 3420   149571       S. Pellissier   39              Italy       72         72
# 3550    29552         S. Nakamura   40              Japan       72         72
# 3603    16254           T. Howard   39      United States       72         72
# 4062   159520        N. Fernández   39          Argentina       71         71
# 4187   156483        C. Lucchetti   40          Argentina       71         71
# 4228     3665            B. Nivet   41             France       71         71
# 4640    16097          N. Rimando   39      United States       71         71
# 4646   142818           F. Cubero   39          Argentina       71         71
# 4741   140029            O. Pérez   45             Mexico       71         71
# 5040   142670            R. Braña   39          Argentina       70         70
# 5101   105308           J. Gillet   39            Belgium       70         70
# 5608   156662           A. Bastía   39          Argentina       70         70
# 6398   159436           R. Zapata   39           Colombia       69         69
# 6861    49212          J. Speroni   39          Argentina       68         68
# 7039   136553       Lee Dong Gook   39     Korea Republic       68         68
# 7225   142998            C. Muñoz   41          Argentina       68         68
# 7427   146636           José Juan   39              Spain       68         68
# 9484   176540         B. Castillo   40           Colombia       66         66
# 10356   49511            F. Kippe   40             Norway       65         65
# 10487  162952          M. Caranta   39          Argentina       65         65
# 10534  140180        M. Ogasawara   39              Japan       65         65
# 10545  140183         S. Narazaki   42              Japan       65         65
# 11456  152690  D. Konstantopoulos   39             Greece       64         64
# 12192  208927        H. Sulaimani   41       Saudi Arabia       63         63
# 12453  214372             W. Díaz   40           Colombia       63         63
# 14129  156480         Y. Nakazawa   40              Japan       61         61
# 14920   53352           D. Bulman   39            England       60         60
# 15133  104900           M. Gurski   39            Germany       60         60
# 15426   18745            M. Tyler   41            England       59         59
# 16264   28157     P. van der Vlag   40        Netherlands       58         58
# 16489    2702          K. Ellison   39            England       57         57
# 16596  219344        A. Al Basisi   40       Saudi Arabia       57         57
# 17672  237744            R. Kawai   39              Japan       53         53
# 17726   51963           T. Warner   44  Trinidad & Tobago       53         53
# 17752  100899         S. Phillips   40            England       52         52
# 17842  182461           Zhou Ting   39           China PR       52         52
# 18183   53748       K. Pilkington   44            England       48         48
#
#                                Club   Value  Wage Preferred Foot  \
# 41              Paris Saint-Germain  4000.0  77.0          Right
# 554                   Chievo Verona  1000.0  10.0          Right
# 864                 Montpellier HSC     NaN  18.0          Right
# 1120                            NaN     NaN   0.0          Right
# 1294                         Foggia   525.0   2.0          Right
# 1952         Club Atlético Talleres   450.0  10.0           Left
# 2225               SV Werder Bremen  1600.0  18.0          Right
# 2706                       Cádiz CF   270.0   4.0          Right
# 2821                      Patronato   270.0   6.0          Right
# 3128                        Livorno   270.0   2.0          Right
# 3420                  Chievo Verona   900.0  10.0          Right
# 3550                   Júbilo Iwata     NaN   4.0           Left
# 3603                Colorado Rapids   210.0   3.0          Right
# 4062              Unión de Santa Fe   160.0   4.0          Right
# 4187               Atlético Tucumán   160.0   4.0          Right
# 4228                   ESTAC Troyes     NaN   5.0          Right
# 4640                 Real Salt Lake   160.0   3.0          Right
# 4646                Vélez Sarsfield   160.0   6.0          Right
# 4741                        Pachuca   160.0   8.0          Right
# 5040        Estudiantes de La Plata   120.0   6.0          Right
# 5101              Standard de Liège   120.0   4.0           Left
# 5608            Club Atlético Colón   120.0   5.0          Right
# 6398         Independiente Santa Fe    70.0   1.0          Right
# 6861                 Crystal Palace    60.0   8.0          Right
# 7039         Jeonbuk Hyundai Motors   260.0   4.0          Right
# 7225   CD Universidad de Concepción    60.0   1.0          Right
# 7427                       Elche CF    60.0   1.0           Left
# 9484                 Atlético Huila    40.0   1.0          Right
# 10356                 Lillestrøm SK     NaN   1.0           Left
# 10487        Club Atlético Talleres    40.0   2.0          Right
# 10534               Kashima Antlers    40.0   2.0          Right
# 10545                Nagoya Grampus    40.0   1.0          Right
# 11456                 Middlesbrough    30.0   5.0           Left
# 12192                     Ohod Club     NaN   3.0           Left
# 12453           Jaguares de Córdoba     NaN   1.0          Right
# 14129           Yokohama F. Marinos     NaN   1.0          Right
# 14920                  Crawley Town    50.0   1.0          Right
# 15133            SpVgg Unterhaching    10.0   1.0          Right
# 15426           Peterborough United    10.0   1.0          Right
# 16264                      FC Emmen    10.0   1.0          Right
# 16489                     Morecambe    30.0   1.0           Left
# 16596                     Ohod Club    10.0   1.0          Right
# 17672    Hokkaido Consadole Sapporo     NaN   1.0          Right
# 17726            Accrington Stanley     NaN   1.0          Right
# 17752                   Yeovil Town     NaN   1.0          Right
# 17842              Dalian YiFang FC    10.0   1.0          Right
# 18183              Cambridge United     NaN   1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 41                          4.0          1.0       GK    2018
# 554                         2.0          1.0       GK    2016
# 864                         2.0          3.0       CB    2011
# 1120                        2.0          1.0       GK    2016
# 1294                        2.0          1.0       GK    2018
# 1952                        1.0          3.0      LCM    2016
# 2225                        3.0          4.0       ST    2018
# 2706                        1.0          1.0       GK    2015
# 2821                        1.0          1.0       GK    2003
# 3128                        2.0          2.0       CB    2018
# 3420                        2.0          3.0       ST    2002
# 3550                        3.0          3.0      CAM    2017
# 3603                        3.0          1.0       GK    2016
# 4062                        1.0          1.0       GK    2014
# 4187                        1.0          1.0       GK    2012
# 4228                        2.0          3.0      CAM    2012
# 4640                        1.0          1.0       GK    2007
# 4646                        1.0          2.0       CB    2008
# 4741                        2.0          1.0       GK    1991
# 5040                        1.0          3.0      RDM    2016
# 5101                        2.0          1.0       GK    2016
# 5608                        1.0          3.0      CDM    2016
# 6398                        1.0          1.0       GK    2014
# 6861                        1.0          1.0       GK    2004
# 7039                        3.0          2.0       ST    2009
# 7225                        1.0          1.0       GK    2013
# 7427                        1.0          1.0       GK    2017
# 9484                        1.0          1.0       GK    2017
# 10356                       1.0          2.0      LCB    2002
# 10487                       1.0          1.0       GK    2016
# 10534                       2.0          2.0      CDM    1998
# 10545                       2.0          1.0       GK    1999
# 11456                       1.0          1.0       GK    2013
# 12192                       1.0          3.0       LB    2018
# 12453                       1.0          2.0      LCB    2016
# 14129                       2.0          2.0       CB    2002
# 14920                       1.0          2.0       CM    2017
# 15133                       1.0          1.0       GK    2018
# 15426                       1.0          1.0       GK    2016
# 16264                       1.0          1.0       GK    2017
# 16489                       1.0          2.0       LM    2011
# 16596                       1.0          1.0       GK    2014
# 17672                       1.0          2.0       CB    2011
# 17726                       1.0          1.0       GK    2018
# 17752                       1.0          1.0       GK    2017
# 17842                       1.0          2.0       CM    2017
# 18183                       1.0          1.0       GK    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 41              2019-01-01  6.333333   203.0     7400.000000
# 554             2022-01-01  6.083333   187.0     1700.000000
# 864             2019-01-01  5.916667   172.0     4585.060806
# 1120                   NaN  5.916667   187.0     4585.060806
# 1294            2019-01-01  6.166667   196.0      840.000000
# 1952            2019-01-01  5.750000   150.0      675.000000
# 2225            2019-01-01  6.000000   185.0     2800.000000
# 2706            2019-01-01  6.250000   172.0      432.000000
# 2821            2019-01-01  6.083333   179.0      392.000000
# 3128            2019-01-01  6.250000   172.0      419.000000
# 3420            2019-01-01  5.750000   168.0     1500.000000
# 3550            2021-01-01  5.833333   157.0     4585.060806
# 3603            2019-01-01  6.250000   194.0      305.000000
# 4062            2023-01-01  6.416667   187.0      240.000000
# 4187            2019-01-01  6.000000   152.0      240.000000
# 4228            2019-01-01  5.833333   165.0     4585.060806
# 4640            2019-01-01  5.833333   183.0      240.000000
# 4646            2019-01-01  5.750000   159.0      240.000000
# 4741            2021-01-01  5.666667   165.0      272.000000
# 5040            2019-01-01  5.583333   154.0      180.000000
# 5101            2020-01-01  5.916667   190.0      180.000000
# 5608            2019-01-01  5.833333   163.0      180.000000
# 6398            2022-01-01  6.000000   187.0       98.000000
# 6861            2019-01-01  6.083333   176.0      114.000000
# 7039            2020-01-01  6.166667   183.0      338.000000
# 7225            2018-01-01  5.833333   161.0       84.000000
# 7427            2019-01-01  6.000000   181.0       93.000000
# 9484            2021-01-01  6.083333   190.0       54.000000
# 10356           2019-01-01  6.333333   214.0     4585.060806
# 10487           2023-01-01  6.000000   170.0       60.000000
# 10534           2021-01-01  5.666667   159.0       52.000000
# 10545           2021-01-01  6.166667   176.0       50.000000
# 11456           2019-01-01  6.333333   198.0       57.000000
# 12192           2019-01-01  5.666667   154.0     4585.060806
# 12453           2023-01-01  5.833333   168.0     4585.060806
# 14129           2022-01-01  6.166667   172.0     4585.060806
# 14920           2019-01-01  5.750000   165.0       88.000000
# 15133           2019-01-01  6.166667   196.0       15.000000
# 15426           2019-01-01  6.000000   183.0       18.000000
# 16264           2019-01-01  6.083333   168.0       15.000000
# 16489           2019-01-01  5.916667   168.0       53.000000
# 16596           2019-01-01  6.000000   190.0       17.000000
# 17672           2021-01-01  6.000000   165.0     4585.060806
# 17726           2019-01-01  6.333333   185.0     4585.060806
# 17752           2022-01-01  6.083333   165.0     4585.060806
# 17842           2020-01-01  6.083333   163.0       22.000000
# 18183           2023-01-01  6.166667   190.0     4585.060806

# %%
sns.violinplot(data = df  , y = 'Age' , color = 'y')
# Out:
# <AxesSubplot:ylabel='Age'>

# %% [markdown]
# #### Is there a correlation between Value and Overall and viusalize the results with two graphs?**

# %%
df['Value'].corr(df['Overall']) # weak +ve correlation
# Out:
# 0.6318477413577678

# %%
cor = df.corr()[['Value' , 'Overall']].loc[['Value' , 'Overall']]
cor
# Out:
#             Value   Overall
# Value    1.000000  0.631848
# Overall  0.631848  1.000000

# %%
sns.scatterplot(data = df , x = 'Value' , y = 'Overall')
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Overall'>

# %%
sns.heatmap(cor , annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### what are the ratio of the Preferred Foot and visualize with a graph ?

# %%
no = df['Preferred Foot'].value_counts()
ratio = no * 100 / df['Preferred Foot'].value_counts().sum()
ratio
# Out:
# Right    76.871533
# Left     23.128467
# Name: Preferred Foot, dtype: float64

# %%
sns.countplot(data = df , x = 'Preferred Foot')
# Out:
# <AxesSubplot:xlabel='Preferred Foot', ylabel='count'>

# %%
sns.barplot(data = ratio.to_frame() , x = ratio.index , y = ratio)
# Out:
# <AxesSubplot:ylabel='Preferred Foot'>

# %% [markdown]
# #### what are the top 10 average overall clubs and visualize with a graph ?

# %%
top10 = df.groupby('Club')['Overall'].mean().sort_values(ascending = False).head(10)
top10
# Out:
# Club
# Juventus               82.280000
# Napoli                 80.000000
# Inter                  79.750000
# Real Madrid            78.242424
# Milan                  78.074074
# FC Barcelona           78.030303
# Paris Saint-Germain    77.433333
# Roma                   77.423077
# Manchester United      77.242424
# FC Bayern München      77.000000
# Name: Overall, dtype: float64

# %%
top_10 = df[df['Club'].isin(top10.index)]

# %%
sns.barplot(data = top_10 , y = 'Club' , x = 'Overall' , estimator = np.mean , order = top10.index)
# Out:
# <AxesSubplot:xlabel='Overall', ylabel='Club'>

# %% [markdown]
# **What are the top 5 most common nationality and visualize them with a graph?**

# %%
top5 = df['Nationality'].value_counts().sort_values(ascending = False).head()
top5
# Out:
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: Nationality, dtype: int64

# %%
top_5 = df[df['Nationality'].isin(top5.index)]

# %%
sns.countplot(data = top_5 , x = 'Nationality' , order = top5.index)
# Out:
# <AxesSubplot:xlabel='Nationality', ylabel='count'>

# %% [markdown]
# # Great Job!
