# %%
import pandas as pd
import numpy as np
import seaborn as sns 
sns.set(rc = {'figure.figsize':(15,5)})
sns.set_palette('rocket')

# %%
df = pd.read_csv('Superstore.csv' , encoding='windows-1252')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# #### Check the duplicated data

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include = 'all')
# Out:
#               Order ID Order Date   Ship Date       Ship Mode  Customer Name  \
# count             9994       9994        9994            9994           9994
# unique            5009       1237        1334               4            793
# top     CA-2017-100111   9/5/2016  12/16/2015  Standard Class  William Brown
# freq                14         38          35            5968             37
# mean               NaN        NaN         NaN             NaN            NaN
# std                NaN        NaN         NaN             NaN            NaN
# min                NaN        NaN         NaN             NaN            NaN
# 25%                NaN        NaN         NaN             NaN            NaN
# 50%                NaN        NaN         NaN             NaN            NaN
# 75%                NaN        NaN         NaN             NaN            NaN
# max                NaN        NaN         NaN             NaN            NaN
#
# ...

# %% [markdown]
# #### Remove the unnecessary columns

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.drop(['Row ID' , 'Customer ID' , 'Product ID'] , axis = 'columns' , inplace = True)

# %%
df.head(1)
# Out:
#          Order ID Order Date   Ship Date     Ship Mode Customer Name  \
# 0  CA-2016-152156  11/8/2016  11/11/2016  Second Class   Claire Gute
#
#     Segment        Country       City     State  Postal Code Region  \
# 0  Consumer  United States  Henderson  Kentucky        42420  South
#
#     Category Sub-Category                       Product Name   Sales  \
# 0  Furniture    Bookcases  Bush Somerset Collection Bookcase  261.96
#
#    Quantity  Discount   Profit
# 0         2       0.0  41.9136

# %% [markdown]
# ### Univariate Analysis

# %%
#### Distripution of ship mode , segement , country , category
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer Name',
#        'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit'],
#       dtype='object')

# %%
display(df['Ship Mode'].value_counts())
sns.countplot(data = df , x = 'Ship Mode' , order = df['Ship Mode'].value_counts().index)
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
print(df['Segment'].value_counts())
sns.countplot(data = df , x = 'Segment', order = df['Segment'].value_counts().index)
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
print(df['Country'].value_counts())
sns.countplot(data = df , x = 'Country')
df.drop('Country' , axis = 1 , inplace = True)
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
print(df['Category'].value_counts())
sns.countplot(data = df , x = 'Category' , order = df['Category'].value_counts().index)
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# #### What is the most shape class ordered from our website ?

# %%
print(df['Ship Mode'].value_counts())
sns.countplot(data = df , y = 'Ship Mode')
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64
# <AxesSubplot:xlabel='count', ylabel='Ship Mode'>

# %% [markdown]
# #### What is the most segement dealing with our website ?

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sns.countplot(data = df , x = 'Segment')
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %% [markdown]
# #### What is the most ordered category in our website ?

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.countplot(data = df , x = 'Category')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# #### what is the most ordered region ?

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
sns.countplot(data = df , x = 'Region' , order = df['Region'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# ### What is the most ordered customer ?

# %%
top_10 =df['Customer Name'].value_counts().to_frame().head(10).reset_index()
top_10.columns = ['Customer Name' , 'Freq']
top_10
# Out:
#          Customer Name  Freq
# 0        William Brown    37
# 1             John Lee    34
# 2         Matt Abelman    34
# 3           Paul Prost    34
# 4  Chloris Kastensmidt    32
# 5          Seth Vernon    32
# 6     Jonathan Doherty    32
# 7         Edward Hooks    32
# 8     Zuschuss Carroll    31
# 9           Emily Phan    31

# %%
sns.barplot(data = top_10 , y = 'Customer Name' , x = 'Freq' )
# Out:
# <AxesSubplot:xlabel='Freq', ylabel='Customer Name'>

# %% [markdown]
# ### What is the most ordered product ?

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer Name',
#        'Segment', 'City', 'State', 'Postal Code', 'Region', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
top5 = df['Product Name'].value_counts().head().to_frame().reset_index()
top5.rename(columns = {'index':'Product Name' , 'Product Name' : 'Freq'} , inplace = True)

# %%
top5
# Out:
#               Product Name  Freq
# 0          Staple envelope    48
# 1                  Staples    46
# 2        Easy-staple paper    46
# 3  Avery Non-Stick Binders    20
# 4  Staples in misc. colors    19

# %%
sns.barplot(data = top5 , y = 'Product Name' , x = 'Freq')
# Out:
# <AxesSubplot:xlabel='Freq', ylabel='Product Name'>

# %% [markdown]
# ## Take a look at the distripution and Outliers of the numerical Features

# %%
df.describe().drop('Postal Code' , axis = 1)
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### Distribution and outliers of discount

# %%
sns.displot(data = df , x = 'Discount')

# %%
sns.boxplot(data = df , x = 'Discount')
# Out:
# <AxesSubplot:xlabel='Discount'>

# %% [markdown]
# ### distripution and outliers of profit

# %%
sns.displot(data = df , x = 'Profit')

# %%
sns.kdeplot(data = df , x = 'Profit')
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.boxplot(data = df , x = 'Profit')
# Out:
# <AxesSubplot:xlabel='Profit'>

# %% [markdown]
# ### distripution and outliers of sales

# %%
sns.displot(data = df , x = 'Sales')

# %%
sns.kdeplot(data = df , x = 'Sales')
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.boxplot(data = df , x = 'Sales')
# Out:
# <AxesSubplot:xlabel='Sales'>

# %% [markdown]
# # Bivariate / Multivariate Analysis

# %% [markdown]
# #### What is the most profited Segment ?

# %%
df.groupby('Segment')['Profit'].sum().to_frame()
# Out:
#                   Profit
# Segment
# Consumer     134119.2092
# Corporate     91979.1340
# Home Office   60298.6785

# %%
sns.barplot(data = df , x = 'Segment' , y = 'Profit' , estimator = np.sum)
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Profit'>

# %% [markdown]
# #### What is the top 10 profited state ?

# %%
top10 = df.groupby('State')['Profit'].sum().sort_values(ascending = False).head(10).to_frame().reset_index()

# %%
sns.barplot(data = top10 , x = top10.columns[0] , y = top10.columns[1])
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %% [markdown]
# #### What is the most discounted category ?

# %%
top_cat = df.groupby('Category')['Discount'].sum().sort_values(ascending = False)

# %%
sns.barplot(data = df , x = 'Category' , y = 'Discount' , 
            estimator = np.sum , order = top_cat.index)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Discount'>

# %% [markdown]
# ### What is the total profit for each Category in each Region

# %%
dt = df.groupby(['Region' , 'Category'])['Profit'].sum().to_frame().unstack()
dt
# Out:
#               Profit
# Category   Furniture Office Supplies  Technology
# Region
# Central   -2871.0494       8879.9799  33697.4320
# East       3046.1658      41014.5791  47462.0351
# South      6771.2061      19986.3928  19991.8314
# West      11504.9503      52609.8490  44303.6496

# %%
sns.barplot(data = df , x = 'Region' , y = 'Profit' , hue = 'Category' 
            , estimator = np.sum , order = dt.index)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %%
piovt = df.pivot_table(columns = 'Region' , index = 'Category' , values = 'Profit' , aggfunc = np.sum)

# %%
sns.heatmap(piovt , annot = True)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Category'>

# %% [markdown]
# #### Extract Year and Month of order data

# %%
df['Year'] = df['Order Date'].apply(lambda x : x.split('/')[2])
df['Year'].unique()
# Out:
# array(['2016', '2015', '2014', '2017'], dtype=object)

# %%
df['Month'] = df['Order Date'].apply(lambda x : x.split('/')[0])
df['Month'].unique()
# Out:
# array(['11', '6', '10', '4', '12', '5', '8', '7', '9', '1', '3', '2'],
#       dtype=object)

# %% [markdown]
# ### what's is the amount of Discount every month ?

# %%
dt = df.groupby('Month')['Discount'].sum().to_frame().reset_index().sort_values(by = 'Discount', ascending = False)

# %%
sns.barplot(data = df , x = 'Month' , y = 'Discount' , estimator = np.sum , order = dt['Month'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Discount'>

# %% [markdown]
# ### what's is the amount of Discount every month each year ?

# %%
df.groupby(['Year' , 'Month'])['Discount'].sum().to_frame().unstack()
# Out:
#       Discount                                                                 \
# Month        1     10     11     12      2      3      4      5      6      7
# Year
# 2014     10.00  25.45  48.07  53.05   8.10  26.30  14.85  18.95  23.22  24.55
# 2015     10.32  26.95  52.59  43.37   8.30  19.34  28.15  24.25  23.80  23.85
# 2016     11.80  28.85  58.32  47.67   8.00  31.12  26.50  41.50  27.60  32.05
# 2017     25.00  51.92  73.89  67.72  19.47  31.14  39.47  36.89  42.12  31.65
#
#
# Month      8      9
# Year
# 2014   20.05  42.87
# 2015   24.87  41.30
# 2016   32.67  54.24
# 2017   31.30  67.65

# %%
sns.barplot(data = df , x = 'Year' , y = 'Discount' , hue = 'Month' , estimator = np.sum)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Discount'>

# %%
pivt = df.pivot_table(columns = 'Year' , index = 'Month' , values = 'Discount' , aggfunc = np.sum)

# %%
sns.heatmap(pivt , annot = True)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Month'>

# %% [markdown]
# ### what's the effect of Discount on Sales and Profit(Lineplot)

# %%
sns.lineplot(data = df , y = 'Sales' , x = 'Discount' , hue = 'Year' ,estimator = np.sum , ci = True)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Sales'>

# %%
sns.lineplot(data = df , x = 'Discount' , y = 'Profit' , hue = 'Year' , estimator = np.sum , ci = True)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# ### what is the total sells for each region each year ?

# %%
df.groupby(['Region' , 'Year'])['Sales'].sum().to_frame().unstack()
# Out:
#                Sales
# Year            2014         2015         2016         2017
# Region
# Central  103838.1646  102874.2220  147429.3760  147098.1282
# East     128680.4570  156332.0570  180685.8220  213082.9040
# South    103845.8435   71359.9805   93610.2235  122905.8575
# West     147883.0330  139966.2495  187480.1765  250128.3655

# %%
sns.barplot(data = df , x = 'Region' , y = 'Sales' , hue = 'Year' , estimator = np.sum , ci = True)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
pivt = df.pivot_table(columns = 'Region' , index = 'Year' , values = 'Sales' , aggfunc = np.sum)

# %%
sns.heatmap(pivt , annot = True)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Year'>

# %% [markdown]
# #### What is the most type of cutomer and with whcih segment dealing with our company ?

# %%
sns.countplot(data = df , x = 'Ship Mode' , hue = 'Segment')
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
df['count'] = np.ones(len(df))
df.groupby(['Ship Mode' , 'Segment'])['count'].value_counts().to_frame().unstack()
# Out:
#                            count
# count                        1.0
# Ship Mode      Segment
# First Class    Consumer      769
#                Corporate     485
#                Home Office   284
# Same Day       Consumer      317
#                Corporate     114
#                Home Office   112
# Second Class   Consumer     1020
#                Corporate     609
#                Home Office   316
# Standard Class Consumer     3085
#                Corporate    1812
#                Home Office  1071

# %%
pivt = df.pivot_table(columns = 'Ship Mode' , index = 'Segment' , values = 'count' , aggfunc = np.sum)
pivt
# Out:
# Ship Mode    First Class  Same Day  Second Class  Standard Class
# Segment
# Consumer           769.0     317.0        1020.0          3085.0
# Corporate          485.0     114.0         609.0          1812.0
# Home Office        284.0     112.0         316.0          1071.0

# %%
sns.heatmap(pivt , annot = True)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Segment'>
